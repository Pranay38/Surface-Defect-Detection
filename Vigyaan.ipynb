# %%
# !pip install torch
# Out:
# ...
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/7b/7c/4d8728e6f8dbe2b8af054bd92c290d94c633270443514e3ee4b768125cf9/torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 990.5 kB/s eta 0:00:00:0100:020mm
# ...

# %% [markdown]
# # Installing Yolov5

# %%
import torch
from IPython.display import Image 
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.60 MiB | 10.13 MiB/s, done.
# Resolving deltas: 100% (10987/10987), done.
# /Users/pranayagrawal/Desktop/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/8a/7e/20f7e45878b5aed34320fbeeae8f78acc806e7bd708d00b1c6e64b016f5b/GitPython-3.1.37-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-python>=4.1.1 from https://files.pythonhosted.org/packages/a1/f6/57de91ea40c670527cd47a6548bf2cbedc68cec57c041793b256356abad7/opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/dd/48/85ef87f1548620d7c3743cbe135b90d8cf673fc7b8594361917558d765b6/torchvision-0.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for ultralytics>=8.0.147 from https://files.pythonhosted.org/packages/76/bc/f5dc5cfd3625dde7d873cbe537f9dc2c04f7329fdf238347140ac42f4634/ultralytics-8.0.195-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Installing the dataset to the model

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="k8Eyo3oHMDidqFG838V2")
project = rf.workspace("vigyaan").project("defect-irxl0")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/4f/2c/13ef4a1811365208f7441dae564ea57dad4b58762196b7d8e65860b0cc07/roboflow-1.1.7-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/9d/df/88bc1f767d880d4629d71d6d3907bf89aea4506b828e9ede7d3846a0912d/opencv_python_headless-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for supervision from https://files.pythonhosted.org/packages/51/81/3314df2b9f84c0101ba3980499f2b3d87632e19ceaaeaa922fa7c697fa2c/supervision-0.15.0-py3-none-any.whl.metadata
# ...

# %% [markdown]
# # Training the YOLO model on the dataset

# %%
# !python /Users/pranayagrawal/Desktop/yolov5/train.py --img 640 --epochs 30 --data /Users/pranayagrawal/Desktop/yolov5/Defect-2/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/Users/pranayagrawal/Desktop/yolov5/Defect-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.11.5 torch-2.1.0 CPU
#
# ...

# %%
# !python /Users/pranayagrawal/Desktop/yolov5/detect.py --source /Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/crazing_14_jpg.rf.d4f3493b97ac826908accd65f2d526a9.jpg --weights /Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['/Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt'], source=/Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/crazing_14_jpg.rf.d4f3493b97ac826908accd65f2d526a9.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.11.5 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/crazing_14_jpg.rf.d4f3493b97ac826908accd65f2d526a9.jpg: 640x640 (no detections), 150.1ms
# ...

# %%
# !python /Users/pranayagrawal/Desktop/yolov5/detect.py --source /Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/patches_239_jpg.rf.4b11892e3c0a2259d21a224e54bad7ba.jpg --weights /Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['/Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt'], source=/Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/patches_239_jpg.rf.4b11892e3c0a2259d21a224e54bad7ba.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.11.5 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/pranayagrawal/Desktop/yolov5/Defect-2/test/images/patches_239_jpg.rf.4b11892e3c0a2259d21a224e54bad7ba.jpg: 640x640 2 patchess, 129.0ms
# ...

# %%
# !python /Users/pranayagrawal/Desktop/yolov5/export.py --weights /Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.11.5 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.pt with output shape (1, 25200, 11) (13.8 MB)
#
# ONNX: starting export with onnx 1.14.1...
# ONNX: simplifying with onnx-simplifier 0.4.33...
# ONNX: export success ✅ 2.4s, saved as /Users/pranayagrawal/Desktop/yolov5/runs/train/exp2/weights/best.onnx (27.2 MB)
#
# Export complete (2.8s)
# ...
